# %% [markdown]
# # FigS1: Plot tree accuracy vs num of MS targets (downsample)
# - Goal is to compare different probe sets with different types of microsatellite
# - This notebook compares homopolymer 10-14bp vs 15-50bp from two probe sets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import glob
import re
import os

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ```bash
# #!/bin/bash
# nextflow run ~/software/RETrace2/main.nf \
#             --samplesheet 20230117_HCT116_1nt12k10to14bp_samplesheet.csv \
#             --output_dir results_1nt12k10-14bp_500targets_minqual0 \
#             --output_prefix 20230117_HCT116_1nt12k10-14bp \
#             --genome_base ~/Projects/GenomeDB \
#             --genome hg38 \
#             --target_bed /home/tcheng/software/RETrace/Data/Probe/TW_order.1nt10-14bp.12000probes.info.HipSTR.bed \
#             --min_targets 500 \
#             -resume \
#             -profile docker \
#             --min_qual 0 \
#
#
#
# nextflow run ~/software/RETrace2/main.nf \
#             --samplesheet 20230117_HCT116_1nt12k15to50bp_samplesheet.csv \
#             --output_dir results_1nt12k15-50bp_500targets_minqual0 \
#             --output_prefix 20230117_HCT116_1nt12k15-50bp \
#             --genome_base ~/Projects/GenomeDB \
#             --genome hg38 \
#             --target_bed /home/tcheng/software/RETrace/Data/Probe/TW_order_hg38.1nt.12472probes.info.HipSTR.bed \
#             --min_targets 500 \
#             -resume \
#             -profile docker \
#             --min_qual 0 \
# ```

# %% [markdown]
# ## Downsample targets

# %% [markdown]
# ```bash
# #!/bin/bash
#
# result_dir="/home/tcheng/Projects/RETrace/20230117_NovaSeqSP_HCT116_1nt12k_10-14bp_Nextflow/results_1nt12k10-14bp_500targets_minqual0"
# output_dir="output_500targets_minqual0"
# mkdir -p "$output_dir"
# output_prefix="20230117_HCT116_1nt12k10-14bp"
# target_bed="/home/tcheng/software/RETrace2/resources/targets/hg38/RETrace2.hg38.1nt10-14bp.12000probes.bed"
# sample_sheet="/home/tcheng/Projects/RETrace/20230117_NovaSeqSP_HCT116_1nt12k_10-14bp_Nextflow/20230117_HCT116_1nt12k10to14bp_samplesheet.csv"
#
# for n in {0..29} # number of random sample iterations
# do
# 	for num_targets in {100..600..50} # number of targets to downsample to
# 	do
#         echo -e "$num_targets\t$n\t$output_dir"
#
#         python ~/software/RETrace2/scripts/downsampleTargets.py \
#         --alleleDict $result_dir/hipstr/20230117_HCT116_1nt12k10-14bp.alleleDict.pkl \
#         --target_bed $target_bed \
#         --numTargets $num_targets \
#         --output_alleleDict ${output_dir}/${output_prefix}.alleleDict.$num_targets.$n.pkl \
#         --output_sample_list ${output_dir}/${output_prefix}.sample_list.$num_targets.$n.txt \
#         --random_seed $n
#
#         python ~/software/RETrace2/modules/phylo/build_phylo.py \
#         --alleleDict $output_dir/${output_prefix}.alleleDict.$num_targets.$n.pkl \
#         --sample_list $output_dir/${output_prefix}.sample_list.$num_targets.$n.txt \
#         --prefix $output_dir/${output_prefix}.HipSTR.$num_targets.$n \
#
#         python /home/tcheng/software/RETrace2/scripts/evalPhylo.py\
#         --samplesheet $sample_sheet \
#         --exVivo_rootDist /home/tcheng/software/RETrace/Data/Cell_tree/HCT116_exvivo/exVivo.rootDist.v2.csv \
#         --tree $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.newick-original.txt \
#         --prefix $output_dir/${output_prefix}.HipSTR.$num_targets.$n \
#         --nproc 15 \
#         --distDict $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.distDict.pkl
#
#         python ~/software/RETrace2/modules/phylo/view_phylo.py \
#         --samplesheet $sample_sheet \
#         --tree $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.newick-original.txt \
#         --prefix $output_dir/${output_prefix}.HipSTR.$num_targets.$n \
#         --color_background
#
#         # clean up intermediate files
#         rm $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.distDict.pkl
#
# 	done
# done
#
# #!/bin/bash
#
# result_dir="/home/tcheng/Projects/RETrace/20230117_NovaSeqSP_HCT116_1nt12k_10-14bp_Nextflow/results_1nt12k15-50bp_500targets_minqual0"
# output_dir="output_500targets_minqual0"
# mkdir -p "$output_dir"
# output_prefix="20230117_HCT116_1nt12k15-50bp"
# target_bed="/home/tcheng/software/RETrace2/resources/targets/hg38/RETrace.hg38.1nt15-50bp.12472probes.bed"
# sample_sheet="/home/tcheng/Projects/RETrace/20230117_NovaSeqSP_HCT116_1nt12k_10-14bp_Nextflow/20230117_HCT116_1nt12k15to50bp_samplesheet.csv"
#
# for n in {0..29} # number of random sample iterations
# do
# 	for num_targets in {100..600..50} # number of targets to downsample to
# 	do
#         echo -e "$num_targets\t$n\t$output_dir"
#
#         python ~/software/RETrace2/scripts/downsampleTargets.py \
#         --alleleDict $result_dir/hipstr/20230117_HCT116_1nt12k15-50bp.alleleDict.pkl \
#         --target_bed $target_bed \
#         --numTargets $num_targets \
#         --output_alleleDict ${output_dir}/${output_prefix}.alleleDict.$num_targets.$n.pkl \
#         --output_sample_list ${output_dir}/${output_prefix}.sample_list.$num_targets.$n.txt \
#         --random_seed $n
#
#         python ~/software/RETrace2/modules/phylo/build_phylo.py \
#         --alleleDict $output_dir/${output_prefix}.alleleDict.$num_targets.$n.pkl \
#         --sample_list $output_dir/${output_prefix}.sample_list.$num_targets.$n.txt \
#         --prefix $output_dir/${output_prefix}.HipSTR.$num_targets.$n \
#
#         python /home/tcheng/software/RETrace2/scripts/evalPhylo.py\
#         --samplesheet $sample_sheet \
#         --exVivo_rootDist /home/tcheng/software/RETrace/Data/Cell_tree/HCT116_exvivo/exVivo.rootDist.v2.csv \
#         --tree $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.newick-original.txt \
#         --prefix $output_dir/${output_prefix}.HipSTR.$num_targets.$n \
#         --nproc 15 \
#         --distDict $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.distDict.pkl
#
#         python ~/software/RETrace2/modules/phylo/view_phylo.py \
#         --samplesheet $sample_sheet \
#         --tree $output_dir/${output_prefix}.HipSTR.$num_targets.$n.buildPhylo.newick-original.txt \
#         --prefix $output_dir/${output_prefix}.HipSTR.$num_targets.$n \
#         --color_background
#
# 	done
# done
# ```

# %% [markdown]
# # Path

# %%
# All inputs/outputs use absolute paths so this notebook can be copied to
# software/RETrace2/notebooks/ and run without depending on the working directory.
DATA_DIR = '/home/tony/Scratch/RETrace2/20230117_NovaSeqSP_HCT116_1nt12k_10-14bp'
downsample_dir = os.path.join(DATA_DIR, 'downsample_targets')
if not os.path.isdir(downsample_dir):
    raise FileNotFoundError(f'downsample_dir not found: {downsample_dir}')

data_dict = {
    'Homopolymer 10-14bp': os.path.join(downsample_dir, '1nt12k10-14bp', 'output_500targets_minqual0'),
    'Homopolymer 15-50bp': os.path.join(downsample_dir, '1nt12k15-50bp', 'output_500targets_minqual0'),
}

missing = [f'{name}: {path}' for name, path in data_dict.items() if not os.path.isdir(path)]
if missing:
    raise FileNotFoundError('Missing downsample result directories:\n' + '\n'.join(missing))

figure_dir = downsample_dir
print('DATA_DIR:', DATA_DIR)
print('figure_dir:', figure_dir)

# %% [markdown]
# # Read downsample results

# %%
def get_downsample_stat(eval_path):
    '''
    input: path to *evalPhylo.txt
    output: dictionary with n_target, accuracy, n_target_pair, n_sample
    '''
    
    # only include build path with eval path (some dont have eval path due to low n sample)
    build_path = eval_path.removesuffix(".evalPhylo.txt") + ".buildPhylo.stats.txt"
    
    # get accuracy from evalPhylo.txt
    filename = os.path.basename(eval_path)
    n_target = int(filename.split(".")[2])
    df = pd.read_csv(eval_path, sep="\t", index_col=0)
    all_accuracy = float(df.at["All_Distances", "Percent_Accuracy"]) * 100
    
    # get n_target_pair and n_sample from buildphylo.stats.txt
    with open(build_path) as f:
        for line in f:
            if line.startswith('Number of Samples Analyzed'):
                n_sample = int(re.findall(r'[0-9]+', line)[0])
            if line.startswith('Avg targets shared per pair of cells'):
                n_target_pair = float(re.findall(r'[0-9]+\.[0-9]+', line)[0])
    
    return({'eval_path':eval_path, 'n_target':n_target, 'all_accuracy':all_accuracy, 'n_target_pair':n_target_pair, 'n_sample':n_sample})

# %%
df_list = []

for name, dir in data_dict.items():
    
    eval_path_list = sorted(glob.glob(os.path.join(dir, '*evalPhylo.txt')))
    eval_path_list = [p for p in eval_path_list if os.path.getsize(p) > 0]
    if not eval_path_list:
        raise FileNotFoundError(f'No non-empty *evalPhylo.txt files found in {dir}')
    df = pd.DataFrame([get_downsample_stat(path) for path in eval_path_list])
    
    # add group name
    df['group'] = [name] * df.shape[0]
    df_list.append(df)
    print(f'{name}: {len(eval_path_list)} eval files')
    
df_combined = pd.concat(df_list).reset_index(drop=True).set_index('eval_path')
df_combined.head()
# Out:
#                                                     n_target  all_accuracy  \
# eval_path
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...       100     34.833091
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...       100     31.940701
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...       100     38.720713
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...       100     36.377773
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...       100     36.875389
#
#                                                     n_target_pair  n_sample  \
# eval_path
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...            5.1        41
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...            5.1        41
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...            5.1        41
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...            5.1        41
# /home/tcheng/Projects/RETrace/20230117_NovaSeqS...            5.0        41
#
# ...

# %% [markdown]
# ## Filter to only include data with minimum number of sample
# - this is to ensure each group has enough samples for evaluation

# %%
df_combined_filtered = df_combined.query('n_sample >= 30')
df_combined_filtered.shape
# Out:
# (660, 5)

# %% [markdown]
# # Plot
# - sns lineplot shows mean and 95% confidence interval, random sample 30 times

# %%
fig, ax = plt.subplots(figsize=(6,6), dpi=200)

# Define custom color palette: tab:green for first group, tab:purple for second group
custom_colors = ['tab:green', 'tab:purple']
sns.lineplot(data=df_combined_filtered, x='n_target', y='all_accuracy', hue='group', palette=custom_colors)

ax.set_title('Homopolymer 10-14bp vs 15-50bp\n', fontsize=18)
ax.set_ylabel('Triplet Accuracy (%)', fontsize=14)
ax.set_xlabel('\nNumber of Targets per Cell', fontsize=14)

ax.grid(True, alpha=0.3)
ax.set_ylim(0,109)
ax.set_xticks(np.arange(50,601,50))

# Add horizontal reference line at 33% accuracy
ax.hlines(33, ax.get_xlim()[0], ax.get_xlim()[1], color='gray', linestyle='--', alpha=0.5, linewidth=1)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.legend(fontsize=12, loc="upper left", title="Mean ± 95% Confidence Interval", title_fontsize=12)
plt.tight_layout()
plt.savefig(os.path.join(figure_dir, 'HCT116_homopolymer_downsample_accuracy.pdf'), dpi=200)
plt.show()

# %% [markdown]
# # Regression analysis for more robust comparison

# %%
from scipy import stats

# %%
def calculate_regression_stats(df, group_name):
    """
    Calculate regression statistics for a specific group
    Returns: slope, intercept, r_squared, p_value, std_err
    """
    group_data = df[df['group'] == group_name]
    x = group_data['n_target'].values
    y = group_data['all_accuracy'].values
    
    # Linear regression using scipy
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    r_squared = r_value ** 2
    
    return {
        'group': group_name,
        'slope': slope,
        'intercept': intercept,
        'r_squared': r_squared,
        'p_value': p_value,
        'std_err': std_err,
        'n_points': len(x)
    }

# %%
# Calculate regression statistics for each group
regression_stats = []

for group in df_combined_filtered['group'].unique():
    stats_dict = calculate_regression_stats(df_combined_filtered, group)
    regression_stats.append(stats_dict)

print("Regression analysis completed for groups:", df_combined_filtered['group'].unique())
# Out:
# Regression analysis completed for groups: ['Homopolymer 10-14bp' 'Homopolymer 15-50bp']

# %%
# Display quantitative comparison table
regression_df = pd.DataFrame(regression_stats)
print("Quantitative Regression Analysis:")
print("="*60)
for _, row in regression_df.iterrows():
    print(f"\n{row['group']}:")
    print(f"  Slope: {row['slope']:.4f} (accuracy increase per target)")
    print(f"  R²: {row['r_squared']:.4f} (variance explained)")
    print(f"  P-value: {row['p_value']:.2e}")
    print(f"  Standard Error: {row['std_err']:.4f}")
    print(f"  Data Points: {row['n_points']}")
# Out:
# Quantitative Regression Analysis:
# ...
#
# Homopolymer 10-14bp:
#   Slope: 0.1186 (accuracy increase per target)
#   R²: 0.7966 (variance explained)
#   P-value: 1.86e-115
#   Standard Error: 0.0033
#   Data Points: 330
#
# Homopolymer 15-50bp:
#   Slope: 0.1068 (accuracy increase per target)
#   R²: 0.7234 (variance explained)
#   P-value: 1.46e-93
#   Standard Error: 0.0036
#   Data Points: 330

# %%
# Regression plot with all data points
fig, ax = plt.subplots(figsize=(6, 6), dpi=200)

# Define custom colors for each group
custom_colors = ['tab:green', 'tab:purple']
group_names = df_combined_filtered['group'].unique()

for i, group in enumerate(group_names):
    group_data = df_combined_filtered[df_combined_filtered['group'] == group]
    sns.regplot(data=group_data, x='n_target', y='all_accuracy', 
                label=group, ax=ax, scatter_kws={'alpha':0.6}, ci=None, color=custom_colors[i])

ax.set_title('Regression Lines with All Data Points\n', fontsize=16)
ax.set_ylabel('Triplet Accuracy (%)\n', fontsize=14)
ax.set_xlabel('\nNumber of Targets per Cell', fontsize=14)

ax.grid(True, alpha=0.3)
ax.set_ylim(0, 109)

# Add horizontal reference line at 33% accuracy
ax.hlines(33, ax.get_xlim()[0], ax.get_xlim()[1], color='gray', linestyle='--', alpha=0.5, linewidth=1)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.legend(fontsize=12, bbox_to_anchor=(0.57, 1.05), title_fontsize=12) 
plt.tight_layout()
plt.savefig(os.path.join(figure_dir, 'HCT116_homopolymer_downsample_accuracy_regression.pdf'), dpi=200)
plt.show()

# %% [markdown]
# ## Combined Plots

# %%
# Combined side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(11, 6), dpi=200)
fig.suptitle('Homopolymer 10-14bp vs 15-50bp', fontsize=18)

# Define custom color palette
custom_colors = ['tab:green', 'tab:purple']

# Left: Original lineplot (mean ± 95% CI)
sns.lineplot(data=df_combined_filtered, x='n_target', y='all_accuracy', hue='group', ax=axes[0], palette=custom_colors)
axes[0].grid(True, alpha=0.3)
axes[0].set_ylim(0, 115)
axes[0].legend(bbox_to_anchor=(0.7, 1.1), fontsize=12, title="Mean ± 95% Confidence Interval", title_fontsize=12)

# Right: Regression plot with all data points
group_names = df_combined_filtered['group'].unique()
for i, group in enumerate(group_names):
    group_data = df_combined_filtered[df_combined_filtered['group'] == group]
    sns.regplot(data=group_data, x='n_target', y='all_accuracy', 
                label=group, ax=axes[1], scatter_kws={'alpha':0.6}, ci=None, color=custom_colors[i])

axes[1].grid(True, alpha=0.3)
axes[1].set_ylim(0, 115)
axes[1].legend(bbox_to_anchor=(0.7, 1.1), fontsize=12, title="All Data Points + Regression Line", title_fontsize=12)

for ax in axes:
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.set_ylabel('\nTriplet Accuracy (%)', fontsize=16)
    ax.set_xlabel('\nNumber of Targets per Cell', fontsize=16)
    ax.hlines(33, ax.get_xlim()[0], ax.get_xlim()[1], color='gray', linestyle='--', alpha=0.5, linewidth=1)

plt.tight_layout()
plt.savefig(os.path.join(figure_dir, 'HCT116_homopolymer_downsample_accuracy_10to14bp_combined.pdf'), dpi=200)
plt.show()

# %% [markdown]
# ## Proper Statistical Test: ANCOVA to Compare Slopes

# %%
# Method 1: Using statsmodels for ANCOVA (Analysis of Covariance)
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Prepare data for ANCOVA
# Create dummy variable for group (0 = Homopolymer 10-14bp, 1 = Homopolymer 15-50bp)
df_ancova = df_combined_filtered.copy()
df_ancova['group_numeric'] = (df_ancova['group'] == 'Homopolymer 15-50bp').astype(int)

# Fit ANCOVA model with interaction term
# The interaction term tests if slopes are different between groups
model = ols('all_accuracy ~ n_target + group + n_target:group', data=df_ancova).fit()

print("ANCOVA Results - Testing if Slopes are Significantly Different")
print("=" * 70)
print("Comparing: Homopolymer 10-14bp vs Homopolymer 15-50bp")
print("=" * 70)
print(model.summary())

# Extract the interaction p-value (this is what we care about)
interaction_pvalue = model.pvalues['n_target:group[T.Homopolymer 15-50bp]']
print(f"\n🎯 KEY RESULT:")
print(f"Interaction p-value: {interaction_pvalue:.2e}")
print(f"This tests whether the slopes are significantly different between 10-14bp and 15-50bp groups.")

if interaction_pvalue < 0.001:
    print("*** HIGHLY SIGNIFICANT difference between slopes (p < 0.001) ***")
elif interaction_pvalue < 0.01:
    print("** SIGNIFICANT difference between slopes (p < 0.01) **")
elif interaction_pvalue < 0.05:
    print("* SIGNIFICANT difference between slopes (p < 0.05) *")
else:
    print("No significant difference between slopes (p >= 0.05)")
# Out:
# ANCOVA Results - Testing if Slopes are Significantly Different
# ...
# Comparing: Homopolymer 10-14bp vs Homopolymer 15-50bp
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:           all_accuracy   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     705.1
# Date:                Thu, 18 Dec 2025   Prob (F-statistic):          9.81e-205
# Time:                        00:18:04   Log-Likelihood:                -2454.2
# No. Observations:                 660   AIC:                             4916.
# Df Residuals:                     656   BIC:                             4934.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ...
